# %% [markdown]
# # Importing the libraries

# %%
# Importing required libraries
#import numpy as np
import pandas as pd

# %% [markdown]
# # Reading and Inspecting the dataset

# %%
# Reading the dataset
dataset = pd.read_csv('https://raw.githubusercontent.com/analyticsindiamagazine/MocksDatasets/main/advertising.csv')
#dataset = pd.read_csv('Advertising.csv')

# %%
# Checking top 5 rows
dataset.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
#Checking shape of the dataset
dataset.shape
# Out:
# (200, 4)

# %% [markdown]
# # Defining Features

# %%
# Defining input features (X) and output feature (y)
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
type(y)
# Out:
# numpy.ndarray

# %%
# Checking the shape of input and output features
print('Shape of the input features:', X.shape)
print('Shape of the output features:', y.shape)
# Out:
# Shape of the input features: (200, 3)
# Shape of the output features: (200,)

# %% [markdown]
# # Splitting the dataset into the Training set and Test set

# %%
# Splitting the features into train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Checking the shape of the training and test sets
print('Shape of the training patterns:', X_train.shape, y_train.shape)
print('Shape of the test patterns:', X_test.shape, y_test.shape)
# Out:
# Shape of the training patterns: (160, 3) (160,)
# Shape of the test patterns: (40, 3) (40,)

# %% [markdown]
# # Training the Multiple Linear Regression model

# %%
# Defining a linear regression model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
# Fitting the linear regression model
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Checking the regression coefficients of the fitted model
print('The regression coefficients are:', regressor.coef_)
# Out:
# The regression coefficients are: [ 0.05368006  0.11152624 -0.00351166]

# %%
# Checking the intercept
print('The intercept', regressor.intercept_)
# Out:
# The intercept 4.7732052032698356

# %% [markdown]
# # Predicting the Test set results

# %%
#Making predictions on the test data
y_pred = regressor.predict(X_test)

# Comparing the predicted profit with actual profit
pd.DataFrame(data={'Predicted Sales': y_pred, 'Actual Sales': y_test})
# Out:
#     Predicted Sales  Actual Sales
# 0         10.709889          11.3
# 1          8.686298           8.4
# 2          9.577870          12.0
# 3         24.862080          25.4
# 4         14.655845          16.7
# 5          8.321427           8.7
# 6         10.430480           7.2
# 7         18.445376          18.2
# 8          9.733943           9.2
# 9         17.929080          16.6
# 10        23.369886          24.2
# 11        10.679164          10.6
# 12        13.440323          15.5
# 13        17.174162          20.6
# 14        11.773802          11.8
# 15        13.370727          13.2
# 16        21.260099          17.4
# 17         9.196669           1.6
# 18        14.132018          14.7
# 19        18.926072          17.0
# 20        24.755080          26.2
# 21        12.484812          10.3
# 22        16.571306          16.1
# 23        13.773448          12.9
# 24         7.792991           8.1
# 25        15.196483          15.2
# 26        14.716079          17.6
# 27        20.738621          22.6
# 28        17.010419          16.6
# 29         8.834744           8.5
# 30        12.094244          12.5
# 31        20.748865          23.7
# 32        21.261480          16.1
# 33        21.904201          21.8
# 34         7.080871           5.6
# 35         7.044317           6.7
# 36         9.159499           9.7
# 37        15.477961          17.9
# 38        13.282823          13.6
# 39         7.237699           7.2

# %% [markdown]
# # Evaluation Metrics

# %%
# Mean Squared Error (MSE)
from sklearn.metrics import mean_squared_error
MSE=mean_squared_error(y_test, y_pred)
print('Mean Squared Error is:', MSE)
# Out:
# Mean Squared Error is: 4.522552562041288

# %%
# Root Mean Squared Error (RMSE)
import math
RMSE = math.sqrt(MSE)
print('Root Mean Squared Error is:', RMSE)
# Out:
# Root Mean Squared Error is: 2.1266293899128943

# %%
# R-Squared
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print('R-Squared is:', r2)
# Out:
# R-Squared is: 0.8645053923967725

# %%
# Adjusted R-Squared
adj = 1-(
          (1-r2)*(X_train.shape[0]-1)/
           (X_train.shape[0]-X_train.shape[1]-1)
           )
print('Adjusted R-Squared is:', adj)
# Out:
# Adjusted R-Squared is: 0.8618997268659412

# %%
type(y_test)
# Out:
# numpy.ndarray

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(y_test, regressor.predict(X_test))

# %%
plt.scatter(y_test, y_pred, color = "red")
plt.plot(np.sort(y_test), np.sort(regressor.predict(X_test)))

# %%
plt.plot(X_train, regressor.predict(X_train))
# Out:
# [<matplotlib.lines.Line2D at 0x79a1f12ab400>,
#  <matplotlib.lines.Line2D at 0x79a1f12ab460>,
#  <matplotlib.lines.Line2D at 0x79a1f12ab490>]

# %%
np.sort(X_train)
# Out:
# array([[ 36.9,  38.6,  65.6],
#        [  2.2,  24.6,  31.5],
#        [ 12.6,  29.3, 142.9],
#        [ 10.7,  20.6, 209.6],
#        [ 23.6,  57.6, 215.4],
#        [  8.4,  29.6, 102.7],
#        [  1. ,   2.1,   8.6],
#        [ 16.9,  43.7,  89.4],
#        [ 36.9,  79.2, 125.7],
#        [  5.7,  34.4, 104.6],
#        [ 14.3,  31.7, 109.8],
#        [ 32.3,  74.2, 229.5],
#        [ 21.3,  30. , 253.8],
#        [ 21. ,  22. , 184.9],
#        [ 20.6,  25.8,  44.7],
#        [ 12.6,  18.3,  62.3],
#        [ 28.3,  43.2, 292.9],
#        [ 18.1,  30.7, 172.5],
#        [ 22.3,  31.6, 202.5],
#        [  7.3,  28.1,  41.4],
#        [  2.9,  43. , 265.2],
#        [  3.5,   5.9, 197.6],
#        [  5.4,  27.4, 218.5],
#        [ 19.1,  23.9, 147.3],
#        [ 37.7,  39.7, 171.3],
#        [ 33.5,  59. , 217.7],
#        [ 15.9,  28.8, 262.7],
#        [  7.4,  36.8, 163.5],
#        [  3.6,   9.6, 100.4],
#        [ 16. ,  27.5,  76.3],
#        [  1.7,  43.9, 184.9],
#        [  4.9,   9.3, 134.3],
#        [ 28.9,  59.7, 273.7],
#        [ 36.3, 100.9, 296.4],
#        [ 14.8,  38.9,  96.2],
#        [ 47.8,  51.4, 109.8],
#        [  5.5,  26.9, 255.4],
#        [ 32.9,  46. , 204.1],
#        [ 16.7,  22.9, 240.1],
#        [ 35.4,  75.6, 193.7],
#        [ 18.2,  28.7, 191.1],
#        [  9.9,  35.7,  89.7],
#        [ 20.5,  25.9,  43. ],
#        [  3.7,  13.8,  38.2],
#        [  0.4,  13.1,  25.6],
#        [ 15.5,  27.3, 239.3],
#        [ 17.2,  45.9,  69.3],
#        [  9.3,  29.5, 210.7],
#        [  9.3,  25.6,  39. ],
#        [  6.4,   9.3, 177. ],
#        [  8.4,  26.4, 206.9],
#        [  5.8,  24.2,  66.1],
#        [  6. ,  35.6, 149.7],
#        [  5.7,  31.3, 129.4],
#        [  4.9,   8.1,  94.2],
#        [  2.3,  23.7, 276.7],
#        [ 41.8,  48.9, 276.9],
#        [  7.8,  38.9,  50.6],
#        [ 36.5,  72.3, 250.9],
#        [  2.4,  15.4, 175.7],
#        [ 11.7,  36.9,  45.2],
#        [  6. ,  10.8,  75.5],
#        [  3.1,  34.6, 199.8],
#        [ 37.8,  69.2, 230.1],
#        [ 10.9,  14. , 107.4],
#        [  8.2,  56.5, 225.8],
#        [ 31.6,  52.9, 163.3],
#        [ 28.9,  42.8, 131.1],
#        [  5.2,  19.4, 206.8],
#        [ 33.4,  38.7, 177. ],
#        [ 27.2,  43.9, 216.8],
#        [ 11.7,  36.8,  66.9],
#        [ 15.8,  49.9, 227.2],
#        [ 18.4,  65.7, 193.2],
#        [  7.2,   7.6,  97.5],
#        [ 35.8,  49.3,  85.7],
#        [ 16.9,  26.2, 228.3],
#        [  2.1,  26.6, 139.5],
#        [  8.5,  47. ,  48.3],
#        [ 27.7,  53.4, 218.4],
#        [ 47.7,  52.9, 195.4],
#        [  5.4,   9.4,  29.9],
#        [  5.3,  34.3, 238.2],
#        [ 39.6,  41.7, 216.4],
#        [  4.3,  49.8, 222.4],
#        [  1.6,  20.7,  27.5],
#        [ 41.3,  58.5, 151.5],
#        [ 14.3,  25.6, 139.2],
#        [  5.4,  14.7, 117.2],
#        [ 42. ,  66.2, 283.6],
#        [ 23.5,  32.8,  57.5],
#        [ 11. ,  27.5, 237.4],
#        [ 33.8,  43. , 213.5],
#        [ 18.8,  21.7,  50.4],
#        [  4.1,   5.7,  11.6],
#        [ 20.9,  47.4, 164.5],
#        [ 43.5,  50.5,  93.9],
#        [  1.5,  28.6,  33. ],
#        [  8.6,   8.7, 232.1],
#        [  4. ,  24. , 214.7],
#        [ 16. ,  19.4,  22.3],
#        [ 10.1,  21.4, 280.2],
#        [  4.1,   8.5, 290.7],
#        [ 16.6,  19.2, 136.2],
#        [  0.9,   9.3,  69. ],
#        [ 39.3,  44.5,  45.1],
#        [ 26.8,  46.2, 141.3],
#        [ 18.1,  25.6, 188.4],
#        [  1.8,  27.7, 293.6],
#        [ 46.4,  59. , 137.9],
#        [  2.1,   8.4,  27.2],
#        [  7.1,  12.8, 168.4],
#        [ 39.6,  55.8, 281.4],
#        [ 26.7,  35.1,  43.1],
#        [ 33.5,  45.1, 219.8],
#        [ 46.2,  58.7, 182.6],
#        [  1.3,  24.3, 149.8],
#        [  3.2,  49. , 220.3],
#        [  1.4,   7.4,  95.7],
#        [ 22.9,  27.1, 248.8],
#        [ 34.5,  46.8,  78.2],
#        [  8.4,  48.7, 121. ],
#        [ 17.4,  38.6, 112.9],
#        [ 17.9,  21.6,  37.6],
#        [  0. ,   9.2,  80.2],
#        [ 20.3,  30.2, 248.4],
#        [  1.5,  30. ,  97.2],
#        [ 33.2,  37.9, 220.5],
#        [  6.4,  10.6, 284.3],
#        [ 44.3,  49. , 243.2],
#        [ 16. ,  40.8,  70.6],
#        [ 41.7,  45.9, 135.2],
#        [ 20.3,  32.5,  75.3],
#        [  7.7,  23.1, 116. ],
#        [ 35. ,  52.7,  75.1],
#        [ 11.9,  38. ,  40.3],
#        [  3.6,  42. , 166.8],
#        [ 19.3,  26.8,  33. ],
#        [ 14.2,  28.5, 120.5],
#        [  3.5,  19.5, 262.9],
#        [  3.4,  84.8, 234.5],
#        [  4.1,  36.9, 239.8],
#        [  3.7,  13.9, 286. ],
#        [  3.4,  13.1, 222.4],
#        [  5.8,  39.5,  41.1],
#        [ 32. ,  37.7, 228. ],
#        [ 37.7,  49.6, 210.8],
#        [ 12.9,  17. ,  73.4],
#        [ 25.5,  73.4,  88.3],
#        [ 30.6,  38.7, 199.1],
#        [ 40.6,  63.2, 110.7],
#        [  5. ,  43.8, 266.9],
#        [  5.1,  23.5, 237.4],
#        [  2.6,  21.2, 199.8],
#        [ 17.2,  17.9, 187.9],
#        [ 10.2,  14.5, 139.3],
#        [  4.1,  17.2,  31.6],
#        [  0.8,  14.8,  76.4],
#        [ 18.5,  41.5, 239.9],
#        [ 17. ,  19.6,  20.1]])

# %%
# Defining input features (X) and output feature (y)
X2 = dataset.iloc[:, 0:-3].values
y2 = dataset.iloc[:, -1].values

# %%
X2
# Out:
# array([[230.1],
#        [ 44.5],
#        [ 17.2],
#        [151.5],
#        [180.8],
#        [  8.7],
#        [ 57.5],
#        [120.2],
#        [  8.6],
#        [199.8],
#        [ 66.1],
#        [214.7],
#        [ 23.8],
#        [ 97.5],
#        [204.1],
#        [195.4],
#        [ 67.8],
#        [281.4],
#        [ 69.2],
#        [147.3],
#        [218.4],
#        [237.4],
#        [ 13.2],
#        [228.3],
#        [ 62.3],
#        [262.9],
#        [142.9],
#        [240.1],
#        [248.8],
#        [ 70.6],
#        [292.9],
#        [112.9],
#        [ 97.2],
#        [265.6],
#        [ 95.7],
#        [290.7],
#        [266.9],
#        [ 74.7],
#        [ 43.1],
#        [228. ],
#        [202.5],
#        [177. ],
#        [293.6],
#        [206.9],
#        [ 25.1],
#        [175.1],
#        [ 89.7],
#        [239.9],
#        [227.2],
#        [ 66.9],
#        [199.8],
#        [100.4],
#        [216.4],
#        [182.6],
#        [262.7],
#        [198.9],
#        [  7.3],
#        [136.2],
#        [210.8],
#        [210.7],
#        [ 53.5],
#        [261.3],
#        [239.3],
#        [102.7],
#        [131.1],
#        [ 69. ],
#        [ 31.5],
#        [139.3],
#        [237.4],
#        [216.8],
#        [199.1],
#        [109.8],
#        [ 26.8],
#        [129.4],
#        [213.4],
#        [ 16.9],
#        [ 27.5],
#        [120.5],
#        [  5.4],
#        [116. ],
#        [ 76.4],
#        [239.8],
#        [ 75.3],
#        [ 68.4],
#        [213.5],
#        [193.2],
#        [ 76.3],
#        [110.7],
#        [ 88.3],
#        [109.8],
#        [134.3],
#        [ 28.6],
#        [217.7],
#        [250.9],
#        [107.4],
#        [163.3],
#        [197.6],
#        [184.9],
#        [289.7],
#        [135.2],
#        [222.4],
#        [296.4],
#        [280.2],
#        [187.9],
#        [238.2],
#        [137.9],
#        [ 25. ],
#        [ 90.4],
#        [ 13.1],
#        [255.4],
#        [225.8],
#        [241.7],
#        [175.7],
#        [209.6],
#        [ 78.2],
#        [ 75.1],
#        [139.2],
#        [ 76.4],
#        [125.7],
#        [ 19.4],
#        [141.3],
#        [ 18.8],
#        [224. ],
#        [123.1],
#        [229.5],
#        [ 87.2],
#        [  7.8],
#        [ 80.2],
#        [220.3],
#        [ 59.6],
#        [  0.7],
#        [265.2],
#        [  8.4],
#        [219.8],
#        [ 36.9],
#        [ 48.3],
#        [ 25.6],
#        [273.7],
#        [ 43. ],
#        [184.9],
#        [ 73.4],
#        [193.7],
#        [220.5],
#        [104.6],
#        [ 96.2],
#        [140.3],
#        [240.1],
#        [243.2],
#        [ 38. ],
#        [ 44.7],
#        [280.7],
#        [121. ],
#        [197.6],
#        [171.3],
#        [187.8],
#        [  4.1],
#        [ 93.9],
#        [149.8],
#        [ 11.7],
#        [131.7],
#        [172.5],
#        [ 85.7],
#        [188.4],
#        [163.5],
#        [117.2],
#        [234.5],
#        [ 17.9],
#        [206.8],
#        [215.4],
#        [284.3],
#        [ 50. ],
#        [164.5],
#        [ 19.6],
#        [168.4],
#        [222.4],
#        [276.9],
#        [248.4],
#        [170.2],
#        [276.7],
#        [165.6],
#        [156.6],
#        [218.5],
#        [ 56.2],
#        [287.6],
#        [253.8],
#        [205. ],
#        [139.5],
#        [191.1],
#        [286. ],
#        [ 18.7],
#        [ 39.5],
#        [ 75.5],
#        [ 17.2],
#        [166.8],
#        [149.7],
#        [ 38.2],
#        [ 94.2],
#        [177. ],
#        [283.6],
#        [232.1]])

# %%
# Splitting the features into train and test sets
from sklearn.model_selection import train_test_split
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size = 0.1, random_state = 0)

# %%
X_train2.shape, X_test2.shape, y_train2.shape, y_test2.shape
# Out:
# ((180, 1), (20, 1), (180,), (20,))

# %%
# Defining a linear regression model
from sklearn.linear_model import LinearRegression
regressor2 = LinearRegression()

# %%
# Fitting the linear regression model
regressor2.fit(X_train2, y_train2)
# Out:
# LinearRegression()

# %%
plt.scatter(X_test2, y_test2, color = "red")
plt.plot(X_train2, regressor2.predict(X_train2), color = "green")
plt.title("Linear Regression")
plt.xlabel("Ad Spent")
plt.ylabel("Predicted Sales")
plt.show()

# %%
plt.scatter(X_train2, y_train2, color = "red")
plt.plot(X_train2, regressor2.predict(X_train2), color = "green")
plt.title("Linear Regression")
plt.xlabel("Ad Spent")
plt.ylabel("Predicted Sales")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:,0], X_train[:,1], y_train, marker='.', color='red')
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("y")

coefs = regressor.coef_
intercept = regressor.intercept_
xs = np.tile(np.arange(61), (61,1))
ys = np.tile(np.arange(61), (61,1)).T
zs = xs*coefs[0]+ys*coefs[1]+intercept

ax.plot_surface(xs,ys,zs, alpha=0.5)
plt.show()
